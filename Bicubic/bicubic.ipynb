# %%
#from google.colab import drive 
#drive.mount('/content/drive')

# %cd /content/drive/My\ Drive/SYS843/Bicubic
# Out:
# /content/drive/My Drive/SYS843/Bicubic

# %%
# !python bicubic.py
# Out:
# Start bicubic interpolation
# It will take a little while...
# Progress:[=>                             ] 4.5%Traceback (most recent call last):
#   File "bicubic.py", line 95, in <module>
#     dst = bicubic(img, ratio, a)
#   File "bicubic.py", line 81, in bicubic
#     sys.stderr.write('\r\033[K' + get_progressbar_str(inc/(C*dH*dW)))
# KeyboardInterrupt
