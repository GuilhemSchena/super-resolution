# %% [markdown]
# **Config**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/SYS843/Github/sr/SRCNN_yjn870/
# Out:
# /content/drive/MyDrive/SYS843/Github/sr/SRCNN_yjn870

# %% [markdown]
# **Préparation données**

# %%
# !python prepare.py --scale 2 --images-dir "/content/drive/MyDrive/SYS843/Github/sr/datasets/g100t91aug" --output-path "/content/drive/MyDrive/SYS843/Github/sr/SRCNN_yjn870/train_files/g100t91aug.h5"
# Out:
# train
# tcmalloc: large alloc 1810620416 bytes == 0x562c24910000 @  0x7f41e7bc71e7 0x7f41e441846e 0x7f41e4468c7b 0x7f41e446be83 0x7f41e446c07b 0x7f41e450d761 0x562bef3494b0 0x562bef349240 0x562bef3bd0f3 0x562bef34aafa 0x562bef3b8915 0x562bef3b79ee 0x562bef3b76f3 0x562bef4814c2 0x562bef48183d 0x562bef4816e6 0x562bef459163 0x562bef458e0c 0x7f41e69b1bf7 0x562bef458cea
# tcmalloc: large alloc 1810620416 bytes == 0x562c907ce000 @  0x7f41e7bc71e7 0x7f41e441846e 0x7f41e4468c7b 0x7f41e446be83 0x7f41e446c07b 0x7f41e450d761 0x562bef3494b0 0x562bef349240 0x562bef3bd0f3 0x562bef34aafa 0x562bef3b8915 0x562bef3b79ee 0x562bef3b76f3 0x562bef4814c2 0x562bef48183d 0x562bef4816e6 0x562bef459163 0x562bef458e0c 0x7f41e69b1bf7 0x562bef458cea

# %% [markdown]
# **Entraînement**

# %%
# !python train.py --train-file "train_files/g100t91aug_x2.h5" \
                --eval-file "eval_files/Set5_x2.h5" \
                --outputs-dir "weights/g100t91aug_x2_weights" \
                --scale 2 \
                --lr 1e-3 \
                --batch-size 16 \
                --num-epochs 300 \
                --num-workers 8 \
                --seed 123
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch: 0/299: 100% 415648/415648 [14:44<00:00, 469.79it/s, loss=0.000740]
# eval psnr: 35.92
# epoch: 1/299: 100% 415648/415648 [10:39<00:00, 649.88it/s, loss=0.000504]
# eval psnr: 36.21
# epoch: 2/299: 100% 415648/415648 [10:38<00:00, 651.43it/s, loss=0.000483]
# eval psnr: 36.39
# epoch: 3/299: 100% 415648/415648 [10:48<00:00, 641.04it/s, loss=0.000472]
# eval psnr: 36.49
# epoch: 4/299: 100% 415648/415648 [10:40<00:00, 648.72it/s, loss=0.000465]
# eval psnr: 36.52
# ...

# %%
while True:pass

# %% [markdown]
# **Test**

# %%
# !python test.py --weights-file "/content/drive/MyDrive/SYS843/Github/sr/SRCNN_yjn870/weights/91-image_x4_weights/x4/best.pth" \
               --image-file "data/set5/woman.png" \
               --scale 4
# Out:
# PSNR: 29.96
# Runtime of the program bicubic is 0.7468953132629395
# Runtime of the program with upsampling is 1.069124460220337
# Runtime of the program is 0.30216526985168457
