# %% [markdown]
# **Config**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/SYS843/Github/sr/DRCN/
# Out:
# /content/drive/MyDrive/SYS843/Github/sr/DRCN

# %%
# !pip uninstall scipy
# !pip install scipy==1.1.0

# !pip uninstall tensorflow
# !pip install tensorflow==1.15
# Out:
# Found existing installation: scipy 1.4.1
# Uninstalling scipy-1.4.1:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/scipy-1.4.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/scipy/*
# Proceed (y/n)? y
#   Successfully uninstalled scipy-1.4.1
# ...
#      |████████████████████████████████| 31.2 MB 1.8 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# plotnine 0.6.0 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# jax 0.2.25 requires scipy>=1.2.1, but you have scipy 1.1.0 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Would remove:
# ...

# %% [markdown]
# **Entraînement**

# %%
# !python main.py --data_dir "/content/drive/MyDrive/SYS843/Github/sr/datasets" --training_set "T91" --stride_size 14 --batch_size 33 --scale 2 --nb_epochs 300 --batch_num 16
# Out:
# WARNING:tensorflow:From main.py:161: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Super Resolution (tensorflow version:1.15.0)
# 2021/12/15 14:48:26
#
# WARNING:tensorflow:From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:117: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1215 14:48:26.029156 140395277375360 module_wrapper.py:139] From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:117: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:119: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# ...

# %% [markdown]
# **Test**

# %%
# !python test.py --file "/content/drive/MyDrive/SYS843/Github/sr/datasets/Set5/img_001.png" --feature_num 96 --inference_depth 9 --scale 4
#!python test.py --file "data/mesimages/zebra.png" --end_lr 1e-4 --feature_num 32 --inference_depth 5 --scale 2
#!python test.py --file "data/Set5/img_001.png" --feature_num 96 --inference_depth 9 --scale 2
#!python main.py --is_training "False" --dataset "set5" --feature_num 256 --inference_depth 16 --scale 2
# Out:
# WARNING:tensorflow:From test.py:94: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# Super Resolution (tensorflow version:1.15.0)
# 2021/12/11 17:22:58
#
# WARNING:tensorflow:From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:117: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1211 17:22:58.501500 140281023051648 module_wrapper.py:139] From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:117: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/SYS843/Github/sr/DRCN/super_resolution.py:119: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# ...

# %%
# !python augmentation.py
# Out:
# Data Augmentation For Training Data
# Loaded [/content/drive/MyDrive/SYS843/Github/sr/datasets/General100/im_025.png]: 229 x 376 x 3
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_025.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_025_v.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_025_h.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_025_hv.png]
# Loaded [/content/drive/MyDrive/SYS843/Github/sr/datasets/General100/im_023.png]: 632 x 458 x 3
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_023.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_023_v.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_023_h.png]
# Saved [/content/drive/MyDrive/SYS843/Github/sr/datasets/T91_aug/im_023_hv.png]
# Loaded [/content/drive/MyDrive/SYS843/Github/sr/datasets/General100/im_022.png]: 365 x 245 x 3
# ...
