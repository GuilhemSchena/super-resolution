# %% [markdown]
# **Config**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/SYS843/Github/sr/FSRCNN_yjn870/
# Out:
# /content/drive/MyDrive/SYS843/Github/sr/FSRCNN_yjn870

# %% [markdown]
# **Préparation des données**

# %%
# !python prepare.py --images-dir "raw_datasets" \
                   --output-path "train_files/91_images" \
                   --scale "2"
# Out:
# Traceback (most recent call last):
#   File "prepare.py", line 86, in <module>
#     train(args)
#   File "/content/drive/MyDrive/SYS843/Github/sr/FSRCNN_yjn870/utils.py", line 15, in wrapper
#     return func(args)
#   File "prepare.py", line 11, in train
#     h5_file = h5py.File(args.output_path, 'w')
#   File "/usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py", line 427, in __init__
#     swmr=swmr)
#   File "/usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py", line 196, in make_fid
#     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 116, in h5py.h5f.create
# OSError: Unable to create file (unable to open file: name = 'train_files/91_images', errno = 21, error message = 'Is a directory', flags = 13, o_flags = 242)

# %% [markdown]
# **Entraînement**

# %%
# !python train.py --train-file "train_files/91-image_x4.h5" \
                 --eval-file "eval_files/Set5_x4.h5" \
                 --outputs-dir "weights/91-image_x4_weights" \
                 --scale 4 \
                 --lr 1e-3 \
                 --batch-size 16 \
                 --num-epochs 300 \
                 --num-workers 8 \
                 --seed 123
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 22000
# epoch: 0/299: 100%|███████| 22000/22000 [01:08<00:00, 320.19it/s, loss=0.013185]
# eval psnr: 23.66
# epoch: 1/299: 100%|███████| 22000/22000 [00:32<00:00, 680.24it/s, loss=0.002908]
# eval psnr: 28.09
# epoch: 2/299: 100%|███████| 22000/22000 [00:32<00:00, 675.53it/s, loss=0.002639]
# eval psnr: 28.63
# epoch: 3/299: 100%|███████| 22000/22000 [00:32<00:00, 678.89it/s, loss=0.002571]
# eval psnr: 28.55
# epoch: 4/299: 100%|███████| 22000/22000 [00:32<00:00, 675.39it/s, loss=0.002541]
# eval psnr: 28.92
# ...

# %% [markdown]
# **Algo**

# %%
# !python test.py --weights-file "weights/91-image_x2_weights/x2/best.pth" \
               --image-file "data/Set5/baby.png" \
               --scale 2
# Out:
# True
# Runtime of the program with upsampling is 0.1270136833190918
# Runtime of the program is 0.1229102611541748
